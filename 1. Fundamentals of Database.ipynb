# %% [markdown]
# <a href="https://colab.research.google.com/github/armahin/SQL/blob/main/1.%20Fundamentals%20of%20Database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FUNDAMENTALS OF DATABASE**

# %% [markdown]
# ---
#
#
# **1. Importance of Data :** From business perspective if we see,
# There were 3 stages firstly when computers arrived then internet after that AI, all these three is related to AI. Till this date we can say, to those who has as many data they are richer. Data is actually money. Google doesn't charge us money for searhing, facebook doesn't charge us for scrolling through the app because they know, they might make some money out of you if they charge but they want your data, if they have your data, they can earn more with that. So till date, data is important. That's why to learn about data is important and with that being said, Database is important cause data is stored in database.Database is programmed with SQL. So SQL is a must know.
#
#
# ---

# %% [markdown]
# ---
#
#
# **2. Database :** Database can be thought as a software what stores our data in an organized way. And we can retrive the data whenever we want in whatever form we want.
#
# *Now where can database be used?*
#
#
#
# **Data Storage:** A database is used to store large amounts of structured data,
# making it easily accessible, searchable, and retrievable.
#
# **Data Analysis:** A database can be used to perform complex data analysis,
# generate reports, and provide insights into the data.
#
# **Record Keeping:** A database is often used to keep track of important records,
# such as financial transactions, customer information, and inventory levels.
#
# **Web Applications:** Databases are an essential component of many web
# applications, providing dynamic content and user management.
#
#
# The good part about database is no matter how complex the application is (like facebook can be an example), all we do is 4 operations:
# These 4 operations together is called `CRUD`.
#
# Where,
#
# *   **C stands for Create**
# *   **R stands for Retrive**
# *   **U stands for Update**
# *   **D stands for Delete**
#
# For an example,
#
#
#
# *   If we register a newUser then we are Creating
# *   If we want to know if that user can login or not, we are Retriving
# *   If we're changing a user's passoword then we are Updating
# *   If we're deleting that user then we are Deleting
#
# Any application if we take, we will see that it's using these 4 opeations on the database.
#
#
#
#
#
#
#
#
#
#
#
#
#
# ---

# %% [markdown]
# ---
#
#
# **3. Properties of an Ideal Database :** Now if we want to know what are the properties of an Ideal Database, we'll see that, these five properties below must remain in a database.
#
# * **Integrity :** Integrity is made up of two words accuracy and consistancy.My name is Mahin,this is accuracy and in future everytime my name will be Mahin, this is consistancy.
#
# * **Availability :** This is very important, 24x7 the database has to be available, there should be zero down time.
# * **Security :** All these important info has to be very very secured.Security has to be carefully implemented into database.
# * **Independent of Application :** Even you have multiple applications, the database has to be same.Like facebook app,web app of facebook then messanger all has to be connected to the same database.
# * **Concurrency :** It means, parallel usage should be happend.Like millions of users come in a website at the same time and all are demanding same info and if we provide that info serially instead of parallely, then the experience will be very poor.That is why database should be concurrent which means millions of request must be served in one go.
#
#
# ---

# %% [markdown]
# ---
# **4. Types of Database :**
#
# The first and the most used database in the world is,
#
# **1. Relational Databases :** Also known as SQL databases, these databases use a relational model to
# organize data into tables with rows and columns.
#
# Suppose, we have a table of Sportsman with some of his data like Name, Age, Gender, Sports and Country
#
# and another table of car owned by that sportsman so clearly both table has the name column.It can visibly be seen that both table has a relationship.So this is relational database.
# ![re.JPG](data:image/jpeg;base64,...)
#
# This is the most used database for obvious reasons as data is mostly formatted in tables and tables connects with each other having relationships.
#
# There are some examples of Relational Databases like, MySQL,Postgre,Oracle,SQLServer,Microsoft Access.
#
#
# **2. NoSQL Databases :** These databases are designed to handle large amounts of unstructured or
# semi-structured data, such as documents, images, or videos. (MongoDB)
#
# NoSQL full form is Not only Sequal.
#
# Previously we've seen relational database where we can store tabular data.In tabular data it has a structure like previously we needed name,sports,gender, age.This is a fixed structure.But all data in the world are not structured. Some data are very unstructured.For an example, let's say in Facebook we're posting a picture and we put a caption.Now after posting it can be seen that how many peoples have liked it,loved it and rest of the reactions and how many of people commented and commented what.How many people have shared the post.And in the comment section, how many likes those comments got and what reply it got and the reply got how many likes or reactions and when did people comment the time is also shown. Now if somebody tells you to store this data in a table, Do you really think this is possible?
# It's not possible actually. Cause this is not a structured data. For this NoSQL database is required.Which is specially designed to store unstructured data. All the big companies in the world are now using NoSQL database in order to store unstructured data.
#
# **3. Column Databases :** These databases store data in columns rather than rows, making them well-
# suited for data warehousing and analytical applications. (Amazon Redshift,Google BigQuery)
#
# Again, relational database is a row based database because every data of an individual is stored in a row form.For an example the sportsperson's database, we've seen how one player's data is stored in a row.So basically relational database stores the data in a row form. But column database stores the data in columns rather than storing the data in rows.
# But why?
# Cause it is well suited for data warehousing and analytical applications.
# Suppose i have data which i want to store.The data is Student Name, College, CGPA.Amd we have 1000 of data.
# Now i can store it in two ways,One way is storing it in row wise and another is in column wise.
# But there is a problem in row wise storing cause let's say somebody is asking me to give him all the student's CGPA only.But firstly we need to see how row data is stored in a memory:
# ![1.JPG](data:image/jpeg;base64,...)
# So if we want to take the CGPA then we first have to go through the name and college.To get all the 1000 CGPA we need to get through another 2000 data (Name+College).Everything needs to be loaded in the memory first to get CGPA. So it's really not efficient. It will take time.But column database solves this problem.
# Let's see how this same info is stored in column database:
# This will make 3 tables of Name,College and CGPA:
# ![re.JPG](data:image/jpeg;base64,...)
#
# So whenever we need the CGPA data it will just to through that CGPA table.
#
# **4. Graph Databases :**
# These databases are used to store and query graph-structured data, such as
# social network connections or recommendation systems. (Neo4j, Amazon
# Neptune)
#
# Sometimes  we get to see this type of data,
# Which is kind of a graph natured.
# ![Graph.JPG](data:image/jpeg;base64,...)
#
# Now if we need to know, which person should be recommended to which person here in the picture so that they can be friends.With nomral databases this cannot be done.To handle this type of problem Graph Databases are used.
#
#
# **5. Key-value databases :**
# These databases store data as a collection of keys and values, making them
# well-suited for caching and simple data storage needs (Redis and Amazon
# DynamoDB)
#
# This is used to do very minor works in the applications.For an example:
#
# Suppose i have a twitter account and in that i can see my profile picture and how many tweets i've tweeted and how much followers i have.
# Now, it's logical to pre-calculate these two data.If i don't then everytime i login to my account, it will calculate my tweets and followers and then show it to me. Twitter will go through all the users that follows me and then will show it to my profile.Can you imagine? How much time would it cost?
# So it needs to be stored in somewhere.
#
#
# ---

# %% [markdown]
# ---
#
#
# # **Relational Databases**
#
# Before diving into, let's see some terminology that is used in database with a table:
#
# ![Relational Database Table.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **What is DBMS?**
#
# A database management system (DBMS) is a software system that provides the
# interfaces and tools needed to store, organize, and manage data in a database. A
# DBMS acts as an intermediary between the database and the applications or users
# that access the data stored in the database.
#
# The database we have, it is controlled from a DBMS. When we talk to database it actually talk to DBMS.
#
# ![DBMS.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# **Keys**
#
# A key in a database is an attribute or a set of attributes that uniquely identifies a
# tuple (row) in a table. Keys play a crucial role in ensuring the integrity and
# reliability of a database by enforcing unique constraints on the data and
# establishing relationships between tables.
#
# **1. Super Key -**
# A Super key is a combination of columns that uniquely identifies any row
# within a relational database management system (RDBMS) table
#
# **2. Candidate key -**
# A candidate key is a minimal Super key, meaning it has no redundant
# attributes. In other words, it's the smallest set of attributes that can be used to
# uniquely identify a tuple (row) in the table
#
# **3. Primary Key -**
# A primary key is a unique identifier for each tuple in a table. There can only be
# one primary key in a table, and it cannot contain null values.
#
# **4. Alternate Key -**
# An alternate key is a candidate key that is not used as the primary key.
#
# **5. Composite Key -**
# A composite key is a primary key that is made up of two or more attributes.
# Composite keys are used when a single attribute is not sufficient to uniquely
# identify a tuple in a table.
#
# **6. Surrogate Key -**
#
# **7. Foreign Key -**
# A foreign key is a primary key from one table that is used to establish a
# relationship with another table.

# %% [markdown]
# **Cardinality of Relationships**
#
# Cardinality in database relationships refers to the number of occurrences of an
# entity in a relationship with another entity. Cardinality defines the number of
# instances of one entity that can be associated with a single instance of the related
# entity.
#
# One-to-one relationship - 1 table
# One-to-many realtionship - 2 tables
# Many-to-many relationship - 3 tables

# %% [markdown]
# **Drawbacks of Databases**
#
# **Complexity:** Setting up and maintaining a database can be complex and time-
# consuming, especially for large and complex systems.
#
# **Cost:** The cost of setting up and maintaining a database, including hardware,
# software, and personnel, can be high.
#
# **Scalability:** As the amount of data stored in a database grows, it can become more
# difficult to manage, leading to performance and scalability issues.
#
# **Data Integrity:** Ensuring the accuracy and consistency of data stored in a database
# can be a challenge, especially when multiple users are updating the data
# simultaneously.
#
# **Security:** Securing a database from unauthorized access and protecting sensitive
# information can be difficult, especially with the increasing threat of cyber attacks.
#
# **Data Migration:** Moving data from one database to another or upgrading to a new
# database can be a complex and time-consuming process.
#
# **Flexibility:** The structure of a database is often rigid and inflexible, making it
# difficult to adapt to changing requirements or to accommodate new types of data.
